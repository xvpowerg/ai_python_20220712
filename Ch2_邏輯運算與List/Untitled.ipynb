# %%
money=50000
cell = int(input("請輸入手機金額:"))
money -= cell
print("剩餘款為:"+str(money))
print("剩餘款為:",money)
print(money)
# Out:
# 請輸入手機金額:600
# 剩餘款為:49400
# 剩餘款為: 49400
# 49400

# %%
a = 16
if a > 18:
 print("大於18")    
print("完成!")
# Out:
# 完成!

# %%
a = 15
if a >= 14:
 a-=2
print(a)
# Out:
# 13

# %% [markdown]
# # 雙向選擇：if else

# %%
a = 16
if a > 18:
    print("大於18")
else:
    print("小於18")
print("完成")
# Out:
# 小於18
# 完成

# %% [markdown]
# # 雙向選擇 if elif

# %%
a = 20
if a > 18:
    print("大於18")
elif a > 12:
    print("大於12")    
else:
    print("小於12")
# Out:
# 大於18

# %% [markdown]
# # 邏輯運算符號
# ![image.png](attachment:image.png)

# %%
a = 6
if a >= 12 and a < 18:
   print("Ok-1") 
else:
   print("cancel-1")

if  12 <= a < 18:
    print("Ok-2")
else:
    print("cancel-2")
    
if not  a > 18:
    print("Ok-3")
else:
    print("cancel-3")
# Out:
# cancel-1
# cancel-2
# Ok-3

# %%
a = 11
if a >= 12 or a < 18:
    print("ok-1")
else:
    print("cancel-1")
# Out:
# ok-1

# %% [markdown]
# # 字串與迴圈

# %% [markdown]
# # while 迴圈

# %%
a = 6
while a > 0:
    print(a)
    a -= 1
print("離開後的a:",a)
# Out:
# 6
# 5
# 4
# 3
# 2
# 1
# 離開後的a: 0

# %%
a = 15
while a > 0:
    print(a)
    a-=2
# Out:
# 15
# 13
# 11
# 9
# 7
# 5
# 3
# 1

# %% [markdown]
# # for 迴圈
#
# python for loop 限定範圍內取值感覺

# %%
print("一個參數")
for i in range(4):
    print(i)
print("離開後的:",i)
# Out:
# 一個參數
# 0
# 1
# 2
# 3
# 離開後的: 3

# %%
for x in range(2):
    print(x)
# Out:
# 0
# 1

# %%
print("兩個參數")
for i in range(4,8):# 4<= a <8
    print(i)
print("離開後的i:",i)
# Out:
# 兩個參數
# 4
# 5
# 6
# 7
# 離開後的x: 7

# %%
for x in range(6,10):# 6<= a < 10
    print(x)
# Out:
# 6
# 7
# 8
# 9

# %%
print("第三個參數")
for i in range(4,0,-1):
    print(i)
print("離開後的i:",i)
# Out:
# 第三個參數
# 4
# 3
# 2
# 1
# 離開後的i: 1

# %%
for i in range(4,8,2):
    print(i)
print("離開後的i:",i)
# Out:
# 4
# 6
# 離開後的i: 6

# %%
for x in range(0,8,2):
    print(x)
# Out:
# 0
# 2
# 4
# 6

# %% [markdown]
# # 迴圈中斷

# %%
i = ['a','b','c','d']

for k in i:
    if k=='c':
        break
    print(k)
# Out:
# a
# b

# %%
i = ['a','b','c','d']
for k in i:
    if k == 'c':
        continue
    print(k)
# Out:
# a
# b
# d

# %%
x=1
while x<=5:  
     if x==3:
       break
     x+=1
     print(x)
# Out:
# 2
# 3

# %% [markdown]
# # 字串

# %%
str = 'This is "Python" '
print(str)
str = "This is \"Python\""
print(str)
str = "test \n test2 \t test3"
print(str)
# Out:
# This is "Python"
# This is "Python"
# test
#  test2 	 test3

# %%
str3 = '''A
"B"
C
'''
str4="""D
'E'
F"""
print(str3)
print(str4)
# Out:
# A
# "B"
# C
#
# D
# 'E'
# F

# %% [markdown]
# # 索引編號與取值
# ![image-2.png](attachment:image-2.png)

# %%
mystring1 = "Hello World"
print(mystring1[0])
print(mystring1[2])
print(mystring1[-1])
print(mystring1[-2])
print(mystring1[2:])
print(mystring1[:3])
print(mystring1[1:4])
# Out:
# H
# l
# d
# l
# llo World
# Hel
# ell

# %%
mystring1 = "Hello World"
print(mystring1[::-1])#倒的顯示
print(mystring1[:-6:-1])
print(mystring1[::2])
# Out:
# dlroW olleH
# dlroW
# HloWrd

# %%
str="This is Python,That is Java;This is SQLite,That is MySQL"
print("原本的字串:",str)
print("替換後:",str.replace("is","-"))
print("替換後2:",str.replace("is","-",2))
# Out:
# 原本的字串: This is Python,That is Java;This is SQLite,That is MySQL
# 替換後: Th- - Python,That - Java;Th- - SQLite,That - MySQL
# 替換後2: Th- - Python,That is Java;This is SQLite,That is MySQL

# %% [markdown]
# ## find

# %%
str1 = "this is Python Tutorial, there"
search1 = "Python"
print(str1.find(search1))
search2 = "not"
print(str1.find(search2))
search3= "t"
print(str1.find(search3))
print(str1.find(search3,4))
print(str1.find(search3,11,20))
# Out:
# 8
# -1
# 0
# 10
# 17

# %%
str1 = "-"
str2 = ("a","b","c")
print(str1.join(str2))
str2 = ("abc","xyz","123")
print(str1.join(str2))
str3 = ":".join("Python")
print(str3)
str4 = "ptyhon-java-c++-ruby"
print(str4.split('-'))
print(str4.split('-',1))
# Out:
# a-b-c
# abc-xyz-123
# P:y:t:h:o:n
# ['ptyhon', 'java', 'c++', 'ruby']
# ['ptyhon', 'java-c++-ruby']

# %% [markdown]
# # List VS Tuple
#
# + tuple 與 list 的差異
#   + 括號不同：
#     + tuple 是用小括號將元素包起來。
#     + list 是用中括號將元素包起來。
# + 元素可否變更：
#    + tuple 決定了元素的內容就不可以變更。
#    + list 可以隨時修改。
# ## list 介紹
# + list 內資料用逗號隔開，放置於中括號的範圍內。
#   + list_name = [1,2,3 ]
# + list 可以儲存不同類型的值或項目，如數字和字串。
#   + list_name = [1, 2, ‘Python’, ‘lists’ ]
# + list 內的資料可以進行增加、更新與移除。
# + 可透過.index( )方法取得指定資料的索引。

# %%
list1 = ['H','i']
tuple1=('H','i')
print(tuple1)
print(list1)
#tuple1[1] = 'a'
list1[1] = 'a'
print(list1)
# Out:
# ('H', 'i')
# ['H', 'i']
# ['H', 'a']

# %%
list1 = ['H','e','l','l','o','W','o','r','l','d']
print(list1)
print(list1[0])
print(list1[1])
print(list1[-1])
print(list1[-3])
# Out:
# ['H', 'e', 'l', 'l', 'o', 'W', 'o', 'r', 'l', 'd']
# H
# e
# d
# r

# %% [markdown]
# ##  List部分取值
# ![image.png](attachment:image.png)

# %%
list1 = ['H','e','l','l','o','W','o','r','l','d']
print(list1[2:])
print(list1[:3])
print(list1[3:5])
# Out:
# ['l', 'l', 'o', 'W', 'o', 'r', 'l', 'd']
# ['H', 'e', 'l']
# ['l', 'o']

# %% [markdown]
# ## 項目附加資料

# %%
list1=[]
print(list1)
list1.append("A")
list1.append("B")
list1.append("C")
print(list1)
myStr = "-".join(list1)
print(myStr)
print(myStr[-1])
# Out:
# []
# ['A', 'B', 'C']
# A-B-C
# C

# %%
myStr = "apple"
print("請輸入-"+myStr[-1]+"-開始的字串")
print(f"請輸入-{myStr[-1]}-開始的字串")
v = input(f"請輸入-{myStr[-1]}-開始的字串")
# Out:
# 請輸入-e-開始的字串
# 請輸入-e-開始的字串
# 請輸入-e-開始的字串qwer

# %%
list1 =['a','b','c']
print(list1)
print(len(list1))
list1.append(["def","qwer"])
print(len(list1))
print(list1)
list2 = ['x','y']
list1 += list2 #展開list2到list1
print(list1)
# Out:
# ['a', 'b', 'c']
# 3
# 4
# ['a', 'b', 'c', ['def', 'qwer']]
# ['a', 'b', 'c', ['def', 'qwer'], 'x', 'y']

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
